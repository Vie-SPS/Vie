# %%
from sam3.model_builder import build_sam3_video_predictor

video_predictor = build_sam3_video_predictor()
video_path = "<Vie/videoexample.mp4>" # a JPEG folder or an MP4 video file
# Start a session
response = video_predictor.handle_request(
    request=dict(
        type="start_session",
        resource_path=video_path,
    )
)
response = video_predictor.handle_request(
    request=dict(
        type="add_prompt",
        session_id=response["session_id"],
        frame_index=0, # Arbitrary frame index
        text="Highlight the people in the video",
    )
)
output = response["outputs"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from sam3.model_builder import build_sam3_video_predictor
#       3 video_predictor = build_sam3_video_predictor()
#       4 video_path = "<Vie/videoexample.mp4>" # a JPEG folder or an MP4 video file
#
# File ~/Vie/sam3/__init__.py:5
#       1 # Copyright (c) Meta Platforms, Inc. and affiliates. All Rights Reserved
#       2
#       3 # pyre-unsafe
# ----> 5 from .model_builder import build_sam3_image_model, build_sam3_predictor
#       7 __version__ = "0.1.0"
#       9 __all__ = ["build_sam3_image_model", "build_sam3_predictor"]
#
# File ~/Vie/sam3/model_builder.py:9
#       6 from typing import Optional
#       8 import pkg_resources
# ----> 9 import torch
#      10 import torch.nn as nn
#      11 from huggingface_hub import hf_hub_download
#
# File /apps/jupyter/6.5.4/lib/python3.10/site-packages/torch/__init__.py:2161
#    2154 from torch._compile import _disable_dynamo  # usort: skip
#    2156 ################################################################################
#    2157 # Import interface functions defined in Python
#    2158 ################################################################################
#    2159
#    2160 # needs to be after the above ATen bindings so we can overwrite from Python side
# -> 2161 from torch import _VF as _VF, functional as functional  # usort: skip
#    2162 from torch.functional import *  # usort: skip # noqa: F403
#    2164 ################################################################################
#    2165 # Remove unnecessary members
#    2166 ################################################################################
#
# File /apps/jupyter/6.5.4/lib/python3.10/site-packages/torch/functional.py:8
#       5 from typing import Any, Optional, TYPE_CHECKING, Union
#       7 import torch
# ----> 8 import torch.nn.functional as F
#       9 from torch import _VF, Tensor
#      10 from torch._C import _add_docstr
#
# File /apps/jupyter/6.5.4/lib/python3.10/site-packages/torch/nn/__init__.py:8
#       1 # mypy: allow-untyped-defs
#       2 from torch.nn.parameter import (  # usort: skip
#       3     Buffer as Buffer,
#       4     Parameter as Parameter,
#       5     UninitializedBuffer as UninitializedBuffer,
#       6     UninitializedParameter as UninitializedParameter,
#       7 )
# ----> 8 from torch.nn.modules import *  # usort: skip # noqa: F403
#       9 from torch.nn import (
#      10     attention as attention,
#      11     functional as functional,
#    (...)
#      16     utils as utils,
#      17 )
#      18 from torch.nn.parallel import DataParallel as DataParallel
#
# File /apps/jupyter/6.5.4/lib/python3.10/site-packages/torch/nn/modules/__init__.py:1
# ----> 1 from .module import Module  # usort: skip
#       2 from .linear import Bilinear, Identity, LazyLinear, Linear  # usort: skip
#       3 from .activation import (
#       4     CELU,
#       5     ELU,
#    (...)
#      32     Threshold,
#      33 )
#
# File /apps/jupyter/6.5.4/lib/python3.10/site-packages/torch/nn/modules/module.py:17
#      15 from torch._prims_common import DeviceLikeType
#      16 from torch.nn.parameter import Buffer, Parameter
# ---> 17 from torch.utils._python_dispatch import is_traceable_wrapper_subclass
#      18 from torch.utils.hooks import BackwardHook, RemovableHandle
#      21 __all__ = [
#      22     "register_module_forward_pre_hook",
#      23     "register_module_forward_hook",
#    (...)
#      30     "Module",
#      31 ]
#
# File /apps/jupyter/6.5.4/lib/python3.10/site-packages/torch/utils/__init__.py:8
#       5 import weakref
#       7 import torch
# ----> 8 from torch.utils import (
#       9     backcompat as backcompat,
#      10     collect_env as collect_env,
#      11     data as data,
#      12     deterministic as deterministic,
#      13     hooks as hooks,
#      14 )
#      15 from torch.utils.backend_registration import (
#      16     generate_methods_for_privateuse1_backend,
#      17     rename_privateuse1_backend,
#      18 )
#      19 from torch.utils.cpp_backtrace import get_cpp_backtrace
#
# File /apps/jupyter/6.5.4/lib/python3.10/site-packages/torch/utils/data/__init__.py:1
# ----> 1 from torch.utils.data.dataloader import (
#       2     _DatasetKind,
#       3     DataLoader,
#       4     default_collate,
#       5     default_convert,
#       6     get_worker_info,
#       7 )
#       8 from torch.utils.data.datapipes._decorator import (
#       9     argument_validation,
#      10     functional_datapipe,
#    (...)
#      14     runtime_validation_disabled,
#      15 )
#      16 from torch.utils.data.datapipes.datapipe import (
#      17     DataChunk,
#      18     DFIterDataPipe,
#      19     IterDataPipe,
#      20     MapDataPipe,
#      21 )
#
# File /apps/jupyter/6.5.4/lib/python3.10/site-packages/torch/utils/data/dataloader.py:24
#      22 import torch
#      23 import torch.distributed as dist
# ---> 24 import torch.utils.data.graph_settings
#      25 from torch._utils import ExceptionWrapper
#      26 from torch.utils.data import _utils
#
# File /apps/jupyter/6.5.4/lib/python3.10/site-packages/torch/utils/data/graph_settings.py:8
#       5 from typing_extensions import deprecated
#       7 import torch
# ----> 8 from torch.utils.data.datapipes.iter.sharding import (
#       9     _ShardingIterDataPipe,
#      10     SHARDING_PRIORITIES,
#      11 )
#      12 from torch.utils.data.graph import DataPipe, DataPipeGraph, traverse_dps
#      15 __all__ = [
#      16     "apply_random_seed",
#      17     "apply_sharding",
#    (...)
#      20     "get_all_graph_pipes",
#      21 ]
#
# File /apps/jupyter/6.5.4/lib/python3.10/site-packages/torch/utils/data/datapipes/__init__.py:1
# ----> 1 from torch.utils.data.datapipes import dataframe as dataframe, iter as iter, map as map
#
# File /apps/jupyter/6.5.4/lib/python3.10/site-packages/torch/utils/data/datapipes/dataframe/__init__.py:1
# ----> 1 from torch.utils.data.datapipes.dataframe.dataframes import (
#       2     CaptureDataFrame,
#       3     DFIterDataPipe,
#       4 )
#       5 from torch.utils.data.datapipes.dataframe.datapipes import DataFramesAsTuplesPipe
#       8 __all__ = ["CaptureDataFrame", "DFIterDataPipe", "DataFramesAsTuplesPipe"]
#
# File /apps/jupyter/6.5.4/lib/python3.10/site-packages/torch/utils/data/datapipes/dataframe/dataframes.py:4
#       1 # mypy: allow-untyped-defs
#       2 from typing import Any, Optional
# ----> 4 from torch.utils.data.datapipes._decorator import functional_datapipe
#       5 from torch.utils.data.datapipes.dataframe.structures import DataChunkDF
#       6 from torch.utils.data.datapipes.datapipe import DFIterDataPipe, IterDataPipe
#
# File /apps/jupyter/6.5.4/lib/python3.10/site-packages/torch/utils/data/datapipes/_decorator.py:7
#       4 from typing import Any, Callable, get_type_hints, Optional, Union
#       6 from torch.utils.data.datapipes._typing import _DataPipeMeta
# ----> 7 from torch.utils.data.datapipes.datapipe import IterDataPipe, MapDataPipe
#      10 ######################################################
#      11 # Functional API
#      12 ######################################################
#      13 class functional_datapipe:
#
# File /apps/jupyter/6.5.4/lib/python3.10/site-packages/torch/utils/data/datapipes/datapipe.py:17
#       9 from torch.utils.data.datapipes.utils.common import (
#      10     _deprecation_warning,
#      11     _iter_deprecated_functional_names,
#      12     _map_deprecated_functional_names,
#      13 )
#      14 from torch.utils.data.dataset import Dataset, IterableDataset
# ---> 17 dill = import_dill()
#      18 HAS_DILL = dill is not None
#      20 __all__ = [
#      21     "DataChunk",
#      22     "DFIterDataPipe",
#      23     "IterDataPipe",
#      24     "MapDataPipe",
#      25 ]
#
# File /apps/jupyter/6.5.4/lib/python3.10/site-packages/torch/utils/_import_utils.py:37, in import_dill()
#      31 import dill
#      33 # XXX: By default, dill writes the Pickler dispatch table to inject its
#      34 # own logic there. This globally affects the behavior of the standard library
#      35 # pickler for any user who transitively depends on this module!
#      36 # Undo this extension to avoid altering the behavior of the pickler globally.
# ---> 37 dill.extend(use_dill=False)
#      38 return dill
#
# AttributeError: module 'dill' has no attribute 'extend'
